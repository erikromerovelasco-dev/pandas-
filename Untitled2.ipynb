# %% [markdown]
# <a href="https://colab.research.google.com/github/erikromerovelasco-dev/pandas-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

orders_a = pd.read_csv('part2_orders_a.csv')
orders_b = pd.read_csv('part2_orders_b.csv')
customers = pd.read_csv('part2_customers.csv')
products = pd.read_csv( 'part2_products.csv')

# %%
orders = pd.concat([orders_a, orders_b], ignore_index=True)

# %%
orders.head()
# Out:
#    order_id  order_date  line_id customer_id product_id  qty channel
# 0      2001  2026-01-02        1        C001        P10    2     web
# 1      2002  2026-01-02        2        C002        P20    1   store
# 2      2003  2026-01-03        3        C003        P20    3     web
# 3      2004  2026-01-04        4        C001        P30    1     app
# 4      2005  2026-01-05        5        C004        P10    5     web

# %%
orders = orders.sort_values(by=['order_date', 'qty'], ascending=[True, False])

# %%
orders.head()
# Out:
#    order_id  order_date  line_id customer_id product_id  qty channel
# 0      2001  2026-01-02        1        C001        P10    2     web
# 1      2002  2026-01-02        2        C002        P20    1   store
# 2      2003  2026-01-03        3        C003        P20    3     web
# 3      2004  2026-01-04        4        C001        P30    1     app
# 4      2005  2026-01-05        5        C004        P10    5     web

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

# %%
orders = orders.set_index('order_date').sort_index()

# %%
orders.head()
# Out:
#             order_id  line_id customer_id product_id  qty channel
# order_date
# 2026-01-02      2001        1        C001        P10    2     web
# 2026-01-02      2002        2        C002        P20    1   store
# 2026-01-03      2003        3        C003        P20    3     web
# 2026-01-04      2004        4        C001        P30    1     app
# 2026-01-05      2005        5        C004        P10    5     web

# %%
orders = orders.merge(customers,
                      on='customer_id',
                      how='left',
                      validate='many_to_one')

# %%
orders.head()
# Out:
#    order_id  line_id customer_id product_id  qty channel customer_name  city  \
# 0      2001        1        C001        P10    2     web           Ana  CDMX
# 1      2002        2        C002        P20    1   store          Luis   GDL
# 2      2003        3        C003        P20    3     web         Marta   MTY
# 3      2004        4        C001        P30    1     app           Ana  CDMX
# 4      2005        5        C004        P10    5     web         Sofia   QRO
#
#      segment
# 0   Consumer
# 1  Corporate
# 2   Consumer
# 3   Consumer
# 4  Small Biz

# %%
orders = orders.merge(products,
                      on='product_id',
                      how='left',
                      validate='many_to_one')
orders
# Out:
#    order_id  order_date  line_id customer_id product_id  qty channel  \
# 0      2001  2026-01-02        1        C001        P10    2     web
# 1      2002  2026-01-02        2        C002        P20    1   store
# 2      2003  2026-01-03        3        C003        P20    3     web
# 3      2004  2026-01-04        4        C001        P30    1     app
# 4      2005  2026-01-05        5        C004        P10    5     web
# 5      2006  2026-01-05        6        C005        P40    1   store
# 6      2007  2026-01-06        7        C002        P30    2     web
# 7      2008  2026-01-07        8        C006        P50    1     app
# 8      2009  2026-01-08        9        C007        P10    1     web
# 9      2010  2026-01-09       10        C008        P20    2   store
#
#         product     category  unit_price
# 0   USB-C Cable  Accessories           8
# 1      Keyboard  Accessories          45
# 2      Keyboard  Accessories          45
# 3   Monitor 24"  Electronics         160
# 4   USB-C Cable  Accessories           8
# 5  Office Chair    Furniture         220
# 6   Monitor 24"  Electronics         160
# 7        Webcam  Electronics          70
# 8   USB-C Cable  Accessories           8
# 9      Keyboard  Accessories          45

# %%
orders['line_total'] = orders['qty'] * orders['unit_price']

# %%
top5 = orders.sort_values(by='line_total', ascending=False).head(5)

# %%
top5
# Out:
#    order_id  order_date  line_id customer_id product_id  qty channel  \
# 6      2007  2026-01-06        7        C002        P30    2     web
# 5      2006  2026-01-05        6        C005        P40    1   store
# 3      2004  2026-01-04        4        C001        P30    1     app
# 2      2003  2026-01-03        3        C003        P20    3     web
# 9      2010  2026-01-09       10        C008        P20    2   store
#
#         product     category  unit_price  line_total
# 6   Monitor 24"  Electronics         160         320
# 5  Office Chair    Furniture         220         220
# 3   Monitor 24"  Electronics         160         160
# 2      Keyboard  Accessories          45         135
# 9      Keyboard  Accessories          45          90
